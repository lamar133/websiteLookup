# %%
import os
from bs4 import BeautifulSoup as soup
import pandas as pd
import urllib
from urllib import request
import re
from geopy.geocoders import Nominatim as nom



def soupTheLink(weblink):
    html = request.urlopen(weblink).read().decode('utf8')
    return soup(html, 'lxml')  

def sliceURL(pTestURL):
    # slices 'http://www' off of url
    updatedURL = pTestURL.replace("http://www.",'').replace("https://www.",'').replace("http://",'').replace("https://",'').replace("www.",'')
    return updatedURL

URL = 'http://www.everynoise.com/'

def collectInfo(pURL):
    
    souped = soupTheLink(pURL)
    
    # Collect site title
    siteTitle = souped.title
    print(siteTitle)
    
    # Collect site description
    siteDescription = souped.find(id='site-description')
    print(siteDescription)
    
    # Collect social media
    commonSocialMedia = ['facebook', 'instagram', 'youtube', 'twitter', 'pinterest', 'linkedin', 'google', 'yelp', 'tumblr', 'github']

    listedURLs = [link.get('href') for link in souped.find_all('a')]
    socialsOnSite=[]

    for link in listedURLs:

        for social in commonSocialMedia:
            if social in link:
                socialsOnSite.append(link)
            else:
                continue
    
    print(socialsOnSite)

    
    # Collect WhoIs source info
    slicedURL = sliceURL(pURL) 
    
    whoIsURL = "https://who.is/whois/" + slicedURL
    print('whoIsURL: ', whoIsURL)
    
    soupedWhoIsURL = soupTheLink(whoIsURL)

    nameNum = 0
    organizationNum = 0
    addressNum = 0
    cityNum = 0
    stateOrProvinceNum = 0
    postalCodeNum = 0
    countryNum = 0
    phoneNum = 0
    emailNum = 0

    registrantName = ""
    registrantOrganization = ""
    registrantAddress = ""
    registrantCity = ""
    registrantStateOrProvince = ""
    registrantPostalCode = ""
    registrantCountry = ""
    registrantPhone = ""
    registrantEmail = ""
    
    adminName = ""
    adminOrganization = ""
    adminAddress = ""
    adminCity = ""
    adminStateOrProvince = ""
    adminPostalCode = ""
    adminCountry = ""
    adminPhone = ""
    adminEmail = ""
    
    technicalName = ""
    technicalOrganization = ""
    technicalAddress = ""
    technicalCity = ""
    technicalStateOrProvince = ""
    technicalPostalCode = ""
    technicalCountry = ""
    technicalPhone = ""
    technicalEmail = ""
    
    for header in soupedWhoIsURL.find_all('strong'):
        
        if header.get_text() == "Name":
            nameNum += 1
            name = header.parent.next_sibling
            
            if nameNum == 1:
                registrantName = name
                print('registrant name: ', name)
            elif nameNum == 2:
                adminName = name
                print('admin name: ', name)
            elif nameNum == 3:
                technicalName = name
                print('technical name: ', name)
        elif header.get_text() == "Organization":
            organizationNum += 1
            organization = header.parent.next_sibling
            
            if organizationNum == 1:
                registrantOrganization = organization
                print('registrant organization: ', organization)
            elif nameNum == 2:
                adminOrganization = organization
                print('admin organization: ', organization)
            elif nameNum == 3:
                technicalOrganization = organization
                print('technical organization: ', organization)
        elif header.get_text() == "Address":
            nameNum += 1
            name = header.parent.next_sibling
            
            if addressNum == 1:
                registrantAddress = address
                print('registrant address: ', address)
            elif addressNum == 2:
                adminAddress = address
                print('admin address: ', address)
            elif addressNum == 3:
                technicalAddress = address
                print('technical address: ', address)
        elif header.get_text() == "City":
            cityNum += 1
            city = header.parent.next_sibling
            
            if cityNum == 1:
                registrantCity = city
                print('registrant city: ', city)
            elif cityNum == 2:
                adminCity = name
                print('admin city: ', city)
            elif cityNum == 3:
                technicalCity = city
                print('technical city: ', city)
        elif header.get_text() == "State / Province":
            stateOrProvinceNum += 1
            stateOrProvince = header.parent.next_sibling
            
            if stateOrProvinceNum == 1:
                registrantStateOrProvince = stateOrProvince
                print('registrant stateOrProvince: ', stateOrProvince)
            elif stateOrProvinceNum == 2:
                adminStateOrProvince = name
                print('admin stateOrProvince: ', stateOrProvince)
            elif stateOrProvinceNum == 3:
                technicalStateOrProvince = stateOrProvince
                print('technical stateOrProvince: ', stateOrProvince)
        elif header.get_text() == "Postal Code":
            postalCodeNum += 1
            postalCode = header.parent.next_sibling
            
            if postalCodeNum == 1:
                registrantPostalCode = postalCode
                print('registrant postalCode: ', postalCode)
            elif postalCodeNum == 2:
                adminPostalCode = postalCode
                print('admin postalCode: ', postalCode)
            elif postalCodeNum == 3:
                technicalPostalCode = postalCode
                print('technical postalCode: ', postalCode)
        elif header.get_text() == "Country":
            countryNum += 1
            country = header.parent.next_sibling
            
            if countryNum == 1:
                registrantCountry = country
                print('registrant country: ', country)
            elif countryNum == 2:
                adminCountry = country
                print('admin country: ', country)
            elif countryNum == 3:
                technicalCountry = country
                print('technical country: ', country)
        elif header.get_text() == "Phone":
            phoneNum += 1
            phone = header.parent.next_sibling
            
            if phoneNum == 1:
                registrantPhone = phone
                print('registrant phone: ', phone)
            elif phoneNum == 2:
                adminPhone = phone
                print('admin phone: ', phone)
            elif phoneNum == 3:
                technicalPhone = phone
                print('technical phone: ', phone)
        elif header.get_text() == "Email":
            emailNum += 1
            email = header.parent.next_sibling
            
            if emailNum == 1:
                registrantEmail = email
                print('registrant email: ', email)
            elif emailNum == 2:
                adminEmail = email
                print('admin email: ', email)
            elif emailNum == 3:
                technicalEmail = email
                print('technical email: ', email)
                
    print("registrantName", registrantName)
    print("registrantOrganization", registrantOrganization)
    print("registrantAddress", registrantAddress)
    print("registrantCity", registrantCity)
    print("registrantStateOrProvince", registrantStateOrProvince)
    print("registrantPostalCode", registrantPostalCode)
    print("registrantCountry", registrantCountry)
    print("registrantPhone", registrantPhone)
    print("registrantEmail ", registrantEmail )
    print("adminName", adminName)
    print("adminOrganization", adminOrganization)
    print("adminAddress", adminAddress)
    print("adminCity", adminCity)
    print("adminStateOrProvince", adminStateOrProvince)
    print("adminPostalCode", adminPostalCode)
    print("adminCountry", adminCountry)
    print("adminPhone", adminPhone)
    print("adminEmail", adminEmail)
    print("technicalName", technicalName)
    print("technicalOrganization", technicalOrganization)
    print("technicalAddress", technicalAddress)
    print("technicalCity", technicalCity)
    print("technicalStateOrProvince", technicalStateOrProvince)
    print("technicalPostalCode", technicalPostalCode)
    print("technicalCountry", technicalCountry)
    print("technicalPhone", technicalPhone)
    print("technicalEmail", technicalEmail)
    
    # Collect Alexa rank
    alexaURL = 'https://www.alexa.com/siteinfo/' + slicedURL
    
    soupedAlexa = soupTheLink(alexaURL)
    score = soupedAlexa.find(class_='metrics-data align-vmiddle').get_text()    
    print('score: ', score)
    keywords=[]
    for header in soupedAlexa.find_all(class_='text-left header'):
        if header.get_text() == 'Keyword':
            keywordTable = header.parent.parent.parent
            for keyword in keywordTable.find_all(class_="topkeywordellipsis"):
                keyword = keyword.get_text()
                keywords.append(keyword[10:])
    print('keywords: ', keywords)
    
    # Collect Timezone
    geolocator = nom()
    location = geolocator.geocode('Toronto Ontario Canada')
    print('lat/lon: ', (location.latitude, location.longitude))
    
    GOOGLE_API_KEY = "AIzaSyBsSTNbL639s13EZm_apopCbxN3-iOySPE"
    googleApiURL = "https://maps.googleapis.com/maps/api/timezone/xml?location=" + str(location.latitude) + "," + str(location.longitude) + "&timestamp=1331161200&key=" + GOOGLE_API_KEY
    soupedGoogle = soupTheLink(googleApiURL)
    timezoneId = soupedGoogle.time_zone_id.get_text()
    timezoneName = soupedGoogle.time_zone_name.get_text()
    print('timezoneId: ', timezoneId)
    print('timezoneName: ', timezoneName)
    
    # Collect eCommerce platform
    
    builtWithURL = "https://api.builtwith.com/v12/api.xml?KEY=dbf200b7-11db-4699-b85b-fac4ed4bae8a&HIDEDL=yes&LOOKUP=" + slicedURL
    soupedBuiltWithURL = soupTheLink(builtWithURL)
    eCommercePlatforms=[]
    for platforms in soupedBuiltWithURL.find_all('category'):
        if platforms.get_text() == 'eCommerce':
            platform = platforms.next_element.next_element
            platform = str(platform)

            if platform[:6] == "<name>":
                eCommercePlatforms.append(platform.replace("<name>",'').replace("</name>",''))

    print("eCommercePlatforms: ", eCommercePlatforms)
    
collectInfo(URL)
# Out:
# None
# None
# []
# whoIsURL:  https://who.is/whois/everynoise.com/
# registrant name:  <div class="col-md-7">glenn mcdonald</div>
# registrant organization:  <div class="col-md-7"></div>
# registrant city:  <div class="col-md-7">Cambridge</div>
# registrant stateOrProvince:  <div class="col-md-7">MA</div>
# registrant postalCode:  <div class="col-md-7">02141</div>
# registrant country:  <div class="col-md-7">US</div>
# registrant phone:  <div class="col-md-7">+1.6172908239</div>
# registrant email:  <div class="col-md-7"><img src="/tools/stringImage?img=8sjDRcUQbtKc2%2BDSYgCVhoLmW55chf8BnUu4riVbc7Y%3D"/></div>
# technical name:  <div class="col-md-7">glenn mcdonald</div>
# technical organization:  <div class="col-md-7"></div>
# admin city:  <div class="col-md-7">Cambridge</div>
# admin stateOrProvince:  <div class="col-md-7">MA</div>
# admin postalCode:  <div class="col-md-7">02141</div>
# admin country:  <div class="col-md-7">US</div>
# ...
